# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/srika/Dropbox/PC/Downloads/day - day.csv")

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        1           1
# 1          2  02-01-2018       1   0     1        0        2           1
# 2          3  03-01-2018       1   0     1        0        3           1
# 3          4  04-01-2018       1   0     1        0        4           1
# 4          5  05-01-2018       1   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        5           1
# 726      727  28-12-2019       1   1    12        0        6           0
# 727      728  29-12-2019       1   1    12        0        0           0
# 728      729  30-12-2019       1   1    12        0        1           1
# 729      730  31-12-2019       1   1    12        0        2           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
df.shape
# Out:
# (730, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        1           1
# 1          2  02-01-2018       1   0     1        0        2           1
# 2          3  03-01-2018       1   0     1        0        3           1
# 3          4  04-01-2018       1   0     1        0        4           1
# 4          5  05-01-2018       1   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        5           1
# 726      727  28-12-2019       1   1    12        0        6           0
# 727      728  29-12-2019       1   1    12        0        0           0
# 728      729  30-12-2019       1   1    12        0        1           1
# 729      730  31-12-2019       1   1    12        0        2           1
#
# ...

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# need to change columns name by readibility easily 
df.rename(columns = {'yr':'year','mnth':'month','hum':'humidity'}, inplace = True)

# %%
df
# Out:
#      instant      dteday  season  year  month  holiday  weekday  workingday  \
# 0          1  01-01-2018       1     0      1        0        1           1
# 1          2  02-01-2018       1     0      1        0        2           1
# 2          3  03-01-2018       1     0      1        0        3           1
# 3          4  04-01-2018       1     0      1        0        4           1
# 4          5  05-01-2018       1     0      1        0        5           1
# ..       ...         ...     ...   ...    ...      ...      ...         ...
# 725      726  27-12-2019       1     1     12        0        5           1
# 726      727  28-12-2019       1     1     12        0        6           0
# 727      728  29-12-2019       1     1     12        0        0           0
# 728      729  30-12-2019       1     1     12        0        1           1
# 729      730  31-12-2019       1     1     12        0        2           1
#
# ...

# %%
df1 = df.duplicated()
df1.sum()
# Out:
# 0

# %%
df1 #there is no duplicates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 725    False
# 726    False
# 727    False
# 728    False
# 729    False
# Length: 730, dtype: bool

# %%
# dropping the unwanted columns
df.drop(['instant','dteday','casual','registered'],axis = 1, inplace =True)

# %%
#mapping season , month , weekday , weathersit columns
df.season = df.season.map({1:'spring',2:'summer', 3:'rainy',4:'winter'})
df.month = df.month.map({1:'jan',2:'feb',3:'mar',4:'aprl',5:'may',6:'jun',7:'july',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'})
df.weekday = df.weekday.map({0:'sun',1:'mon',2:'tue',3:'wed',4:'thu',5:'fri',6:'sat'})
df.weathersit = df.weathersit.map({1:'Clear',2:'Misty',3:'Light_snowrain',4:'Heavy_snowrain'})

# %%
df
# Out:
#      season  year month  holiday weekday  workingday weathersit       temp  \
# 0    spring     0   jan        0     mon           1      Misty  14.110847
# 1    spring     0   jan        0     tue           1      Misty  14.902598
# 2    spring     0   jan        0     wed           1      Clear   8.050924
# 3    spring     0   jan        0     thu           1      Clear   8.200000
# 4    spring     0   jan        0     fri           1      Clear   9.305237
# ..      ...   ...   ...      ...     ...         ...        ...        ...
# 725  spring     1   dec        0     fri           1      Misty  10.420847
# 726  spring     1   dec        0     sat           0      Misty  10.386653
# 727  spring     1   dec        0     sun           0      Misty  10.386653
# 728  spring     1   dec        0     mon           1      Clear  10.489153
# 729  spring     1   dec        0     tue           1      Misty   8.849153
#
#         atemp  humidity  windspeed   cnt
# ...

# %%
df.describe()
# Out:
#              year     holiday  workingday        temp       atemp    humidity  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.500000    0.028767    0.690411   20.319259   23.726322   62.765175
# std      0.500343    0.167266    0.462641    7.506729    8.150308   14.237589
# min      0.000000    0.000000    0.000000    2.424346    3.953480    0.000000
# 25%      0.000000    0.000000    0.000000   13.811885   16.889713   52.000000
# 50%      0.500000    0.000000    1.000000   20.465826   24.368225   62.625000
# 75%      1.000000    0.000000    1.000000   26.880615   30.445775   72.989575
# max      1.000000    1.000000    1.000000   35.328347   42.044800   97.250000
#
#         windspeed          cnt
# count  730.000000   730.000000
# mean    12.763620  4508.006849
# std      5.195841  1936.011647
# min      1.500244    22.000000
# 25%      9.041650  3169.750000
# 50%     12.125325  4548.500000
# 75%     15.625589  5966.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    object
#  1   year        730 non-null    int64
#  2   month       730 non-null    object
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    object
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    object
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   humidity    730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 68.6+ KB

# %% [markdown]
# # visualization

# %%
# given note 'cnt' is dependant variable. so analysing with visualizaton part with independant variable
plt.figure(figsize=(25,18))
plt.subplot(2,4,1)
sns.boxplot(x='season',y='cnt',data = df)
plt.subplot(2,4,2)
sns.boxplot(x='month',y='cnt',data = df)
plt.subplot(2,4,3)
sns.boxplot(x='weekday',y='cnt',data = df)
plt.subplot(2,4,4)
sns.boxplot(x='weathersit',y='cnt',data = df)
plt.subplot(2,4,5)
sns.boxplot(x='holiday',y='cnt',data = df)
plt.subplot(2,4,6)
sns.boxplot(x='workingday',y='cnt',data = df)
plt.subplot(2,4,7)
sns.boxplot(x='year',y='cnt',data = df)
plt.show()

# %% [markdown]
# # Barplot

# %%
def plot_cat_columns(column):
    plt.figure(figsize=(18,12))
    plt.subplot(1,2,1)
    sns.barplot(column,'cnt',data=df)
    plt.subplot(1,2,2)
    sns.barplot(column,'cnt',data=df, hue='year',palette='Set3')
    plt.legend(labels=['2018','2019'])
    plt.show()
plot_cat_columns('season')
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # by the seing the barplot there is high booking in rainy season

# %%
#in month
plot_cat_columns('month')
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # in the months of may , june , july, aug,sep and oct have more booking. and booking for each month have increased from 2018 to 2019

# %%
plot_cat_columns('weathersit')
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # booking increased in 2019 each weather situation by comparing with 2018

# %%
plot_cat_columns('weekday')
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Thu, Fri , Sat and Sun are in high bookind in total week days

# %%
plot_cat_columns('holiday')
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plot_cat_columns('workingday')
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # working days and holidays are looking very closely . and the count increased from 2018 to 2019

# %%
plot_cat_columns('year')
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 2019 have more booking then 2018

# %%
sns.pairplot(data=df,vars=['temp','atemp','humidity','windspeed','cnt'])
plt.show()

# %%
plt.figure(figsize = (10,8))
matrix = np.triu(df[['temp','atemp','humidity','windspeed','cnt']].corr())
sns.heatmap(df[['temp','atemp','humidity','windspeed','cnt']].corr(), annot = True, cmap="RdYlGn", mask=matrix)
plt.title("Correlation between Numerical Variables")
plt.show()

# %% [markdown]
# # there is linear relationship with temp and atemp. im not using in the model due to multicolinearity. and will decide to keep based on VIF and p-value

# %%
# creating dummy variable for month, weekday, weathersit and season
months_df=pd.get_dummies(df.month,drop_first=True)
weekdays_df=pd.get_dummies(df.weekday,drop_first=True)
weathersit_df=pd.get_dummies(df.weathersit,drop_first=True)
seasons_df=pd.get_dummies(df.season,drop_first=True)

# %%
df
# Out:
#      season  year month  holiday weekday  workingday weathersit       temp  \
# 0    spring     0   jan        0     mon           1      Misty  14.110847
# 1    spring     0   jan        0     tue           1      Misty  14.902598
# 2    spring     0   jan        0     wed           1      Clear   8.050924
# 3    spring     0   jan        0     thu           1      Clear   8.200000
# 4    spring     0   jan        0     fri           1      Clear   9.305237
# ..      ...   ...   ...      ...     ...         ...        ...        ...
# 725  spring     1   dec        0     fri           1      Misty  10.420847
# 726  spring     1   dec        0     sat           0      Misty  10.386653
# 727  spring     1   dec        0     sun           0      Misty  10.386653
# 728  spring     1   dec        0     mon           1      Clear  10.489153
# 729  spring     1   dec        0     tue           1      Misty   8.849153
#
#         atemp  humidity  windspeed   cnt
# ...

# %%
df_new = pd.concat([df,months_df,weekdays_df,weathersit_df,seasons_df],axis=1)

# %%
df_new
# Out:
#      season  year month  holiday weekday  workingday weathersit       temp  \
# 0    spring     0   jan        0     mon           1      Misty  14.110847
# 1    spring     0   jan        0     tue           1      Misty  14.902598
# 2    spring     0   jan        0     wed           1      Clear   8.050924
# 3    spring     0   jan        0     thu           1      Clear   8.200000
# 4    spring     0   jan        0     fri           1      Clear   9.305237
# ..      ...   ...   ...      ...     ...         ...        ...        ...
# 725  spring     1   dec        0     fri           1      Misty  10.420847
# 726  spring     1   dec        0     sat           0      Misty  10.386653
# 727  spring     1   dec        0     sun           0      Misty  10.386653
# 728  spring     1   dec        0     mon           1      Clear  10.489153
# 729  spring     1   dec        0     tue           1      Misty   8.849153
#
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 34 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   season          730 non-null    object
#  1   year            730 non-null    int64
#  2   month           730 non-null    object
#  3   holiday         730 non-null    int64
#  4   weekday         730 non-null    object
#  5   workingday      730 non-null    int64
#  6   weathersit      730 non-null    object
#  7   temp            730 non-null    float64
#  8   atemp           730 non-null    float64
#  9   humidity        730 non-null    float64
#  10  windspeed       730 non-null    float64
#  11  cnt             730 non-null    int64
#  12  aug             730 non-null    uint8
#  13  dec             730 non-null    uint8
#  14  feb             730 non-null    uint8
#  15  jan             730 non-null    uint8
#  16  july            730 non-null    uint8
# ...

# %%
#dropping unwanted columns that already create dummy variable out of it
df_new.drop(['season','month','weekday','weathersit'], axis = 1, inplace = True)

# %%
df_new
# Out:
#      year  holiday  workingday       temp     atemp  humidity  windspeed  \
# 0       0        0           1  14.110847  18.18125   80.5833  10.749882
# 1       0        0           1  14.902598  17.68695   69.6087  16.652113
# 2       0        0           1   8.050924   9.47025   43.7273  16.636703
# 3       0        0           1   8.200000  10.60610   59.0435  10.739832
# 4       0        0           1   9.305237  11.46350   43.6957  12.522300
# ..    ...      ...         ...        ...       ...       ...        ...
# 725     1        0           1  10.420847  11.33210   65.2917  23.458911
# 726     1        0           0  10.386653  12.75230   59.0000  10.416557
# 727     1        0           0  10.386653  12.12000   75.2917   8.333661
# 728     1        0           1  10.489153  11.58500   48.3333  23.500518
# 729     1        0           1   8.849153  11.17435   57.7500  10.374682
#
#       cnt  aug  dec  ...  sat  sun  thu  tue  wed  Light_snowrain  Misty  \
# ...

# %%
df_new.shape
# Out:
# (730, 30)

# %% [markdown]
# # the df and df_new have same shape because i created dummies and removed unwanted variables

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            730 non-null    int64
#  1   holiday         730 non-null    int64
#  2   workingday      730 non-null    int64
#  3   temp            730 non-null    float64
#  4   atemp           730 non-null    float64
#  5   humidity        730 non-null    float64
#  6   windspeed       730 non-null    float64
#  7   cnt             730 non-null    int64
#  8   aug             730 non-null    uint8
#  9   dec             730 non-null    uint8
#  10  feb             730 non-null    uint8
#  11  jan             730 non-null    uint8
#  12  july            730 non-null    uint8
#  13  jun             730 non-null    uint8
#  14  mar             730 non-null    uint8
#  15  may             730 non-null    uint8
#  16  nov             730 non-null    uint8
# ...

# %% [markdown]
# # modeling and splitting the data
# and importing related libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from sklearn.metrics import r2_score

# %%
np.random.seed(0)
df_train, df_test = train_test_split(df_new, train_size = 0.7, random_state = 100)

# %%
df_train.shape ,df_test.shape
# Out:
# ((510, 30), (220, 30))

# %%
scaler = MinMaxScaler()

# %%
num_vars = ['temp','atemp','humidity','windspeed','cnt']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train
# Out:
#      year  holiday  workingday      temp     atemp  humidity  windspeed  \
# 576     1        0           1  0.815169  0.766351  0.725633   0.264686
# 426     1        0           0  0.442393  0.438975  0.640189   0.255342
# 728     1        0           1  0.245101  0.200348  0.498067   0.663106
# 482     1        0           0  0.395666  0.391735  0.504508   0.188475
# 111     0        0           0  0.345824  0.318819  0.751824   0.380981
# ..    ...      ...         ...       ...       ...       ...        ...
# 578     1        0           1  0.863973  0.824359  0.679690   0.187140
# 53      0        0           1  0.202618  0.218747  0.435939   0.111379
# 350     0        0           1  0.248216  0.223544  0.577930   0.431816
# 79      0        0           1  0.462664  0.434043  0.759870   0.529881
# 520     1        0           1  0.600225  0.586515  0.632030   0.359599
#
#           cnt  aug  dec  ...  sat  sun  thu  tue  wed  Light_snowrain  Misty  \
# ...

# %%
df_train.describe()
# Out:
#              year     holiday  workingday        temp       atemp    humidity  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.507843    0.025490    0.711765    0.537440    0.513156    0.650480
# std      0.500429    0.157763    0.453386    0.225858    0.212410    0.145846
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.339853    0.332086    0.538643
# 50%      1.000000    0.000000    1.000000    0.542596    0.529718    0.653714
# 75%      1.000000    0.000000    1.000000    0.735215    0.688457    0.754830
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed         cnt         aug         dec  ...         sat  \
# count  510.000000  510.000000  510.000000  510.000000  ...  510.000000
# mean     0.320883    0.513499    0.096078    0.084314  ...    0.129412
# ...

# %%
plt.figure(figsize = (40,40))
matrix = np.triu(df_train.corr())
sns.heatmap(df_train.corr(), annot = True, cmap="RdYlGn", mask=matrix)
plt.show()

# %% [markdown]
# # there is correlation with cnt to year and temp and similarly, misty and humidity. and finally jan and feb month from spring , may month from summer season, and oct and nov months from winter have good correlation

# %%
# Visualizing one of the correlation with Scatter plot.

plt.figure(figsize=[10,10])
plt.scatter(df_train.temp, df_train.cnt)
plt.show()

# %% [markdown]
# # there is positive correlation btw temp and cnt

# %%
#modeling
y_train = df_train.pop('cnt')
X_train = df_train

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('year', True, 1),
#  ('holiday', True, 1),
#  ('workingday', False, 5),
#  ('temp', True, 1),
#  ('atemp', False, 4),
#  ('humidity', True, 1),
#  ('windspeed', True, 1),
#  ('aug', False, 11),
#  ('dec', False, 2),
#  ('feb', False, 3),
#  ('jan', True, 1),
#  ('july', True, 1),
#  ('jun', False, 13),
#  ('mar', False, 16),
#  ('may', False, 10),
#  ('nov', True, 1),
#  ('oct', False, 14),
#  ('sep', True, 1),
#  ('mon', False, 9),
#  ('sat', False, 6),
#  ('sun', False, 7),
#  ('thu', False, 15),
#  ('tue', False, 8),
#  ('wed', False, 12),
#  ('Light_snowrain', True, 1),
#  ('Misty', True, 1),
#  ('spring', True, 1),
#  ('summer', True, 1),
#  ('winter', True, 1)]

# %%
col = X_train.columns[rfe.support_]
print(col)
# Out:
# Index(['year', 'holiday', 'temp', 'humidity', 'windspeed', 'jan', 'july',
#        'nov', 'sep', 'Light_snowrain', 'Misty', 'spring', 'summer', 'winter'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['workingday', 'atemp', 'aug', 'dec', 'feb', 'jun', 'mar', 'may', 'oct',
#        'mon', 'sat', 'sun', 'thu', 'tue', 'wed'],
#       dtype='object')

# %%
def calculateVIF(df):
    vif = pd.DataFrame()
    vif['Features'] = df.columns
    vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return vif

# %%
X_train_rfe = X_train[col]

# %%
calculateVIF(X_train_rfe)
# Out:
#           Features    VIF
# 3         humidity  29.09
# 2             temp  16.80
# 4        windspeed   4.72
# 11          spring   4.37
# 13          winter   3.78
# 12          summer   2.80
# 10           Misty   2.29
# 0             year   2.09
# 5              jan   1.67
# 7              nov   1.60
# 6             july   1.59
# 8              sep   1.40
# 9   Light_snowrain   1.25
# 1          holiday   1.06

# %% [markdown]
# # model building

# %%
X_train_lm_1 = sm.add_constant(X_train_rfe)
lr_1 = sm.OLS(y_train,X_train_lm_1).fit()
print(lr_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     190.8
# Date:                Fri, 29 Jul 2022   Prob (F-statistic):          4.41e-189
# Time:                        14:49:26   Log-Likelihood:                 512.08
# No. Observations:                 510   AIC:                            -994.2
# Df Residuals:                     495   BIC:                            -930.6
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.3032      0.035      8.598      0.000       0.234       0.373
# ...

# %%
# dropping humidity because high VIF values
X_train_new = X_train_rfe.drop(['humidity'], axis = 1)
calculateVIF(X_train_new)
# Out:
#           Features   VIF
# 2             temp  5.15
# 3        windspeed  4.67
# 10          spring  2.76
# 12          winter  2.28
# 11          summer  2.24
# 0             year  2.07
# 4              jan  1.61
# 6              nov  1.60
# 5             july  1.59
# 9            Misty  1.56
# 7              sep  1.35
# 8   Light_snowrain  1.08
# 1          holiday  1.06

# %%
# We can drop nov variable as it has high p-value
X_train_lm_2 = sm.add_constant(X_train_new)
lr_2 = sm.OLS(y_train,X_train_lm_2).fit()
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     196.3
# Date:                Fri, 29 Jul 2022   Prob (F-statistic):          5.93e-186
# Time:                        14:49:32   Log-Likelihood:                 501.87
# No. Observations:                 510   AIC:                            -975.7
# Df Residuals:                     496   BIC:                            -916.5
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2208      0.031      7.190      0.000       0.160       0.281
# ...

# %%
X_train_new = X_train_new.drop(['nov'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#           Features   VIF
# 2             temp  5.13
# 3        windspeed  4.62
# 9           spring  2.75
# 10          summer  2.24
# 0             year  2.07
# 11          winter  1.78
# 4              jan  1.61
# 5             july  1.59
# 8            Misty  1.56
# 6              sep  1.34
# 7   Light_snowrain  1.08
# 1          holiday  1.04

# %%
X_train_lm_3 = sm.add_constant(X_train_new)
lr_3 = sm.OLS(y_train,X_train_lm_3).fit()
print(lr_3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     212.3
# Date:                Fri, 29 Jul 2022   Prob (F-statistic):          8.14e-187
# Time:                        14:49:41   Log-Likelihood:                 501.13
# No. Observations:                 510   AIC:                            -976.3
# Df Residuals:                     497   BIC:                            -921.2
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2154      0.030      7.088      0.000       0.156       0.275
# ...

# %%
# We can drop jan variable as it has high p-value
X_train_new = X_train_new.drop(['jan'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#           Features   VIF
# 2             temp  5.09
# 3        windspeed  4.60
# 9           summer  2.23
# 8           spring  2.08
# 0             year  2.07
# 10          winter  1.78
# 4             july  1.58
# 7            Misty  1.55
# 5              sep  1.34
# 6   Light_snowrain  1.08
# 1          holiday  1.04

# %%
X_train_lm_4 = sm.add_constant(X_train_new)
lr_4 = sm.OLS(y_train,X_train_lm_4).fit()
print(lr_4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     229.6
# Date:                Fri, 29 Jul 2022   Prob (F-statistic):          5.06e-187
# Time:                        14:49:49   Log-Likelihood:                 498.80
# No. Observations:                 510   AIC:                            -973.6
# Df Residuals:                     498   BIC:                            -922.8
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.1994      0.030      6.746      0.000       0.141       0.258
# ...

# %%
# We can drop july variable as it has high p-value
X_train_new = X_train_new.drop(['july'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#          Features   VIF
# 3       windspeed  4.60
# 2            temp  3.84
# 0            year  2.07
# 7          spring  1.99
# 8          summer  1.90
# 9          winter  1.63
# 6           Misty  1.55
# 4             sep  1.23
# 5  Light_snowrain  1.08
# 1         holiday  1.04

# %%
X_train_lm_5 = sm.add_constant(X_train_new)
lr_5 = sm.OLS(y_train,X_train_lm_5).fit()
print(lr_5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     248.4
# Date:                Fri, 29 Jul 2022   Prob (F-statistic):          1.47e-186
# Time:                        14:50:45   Log-Likelihood:                 494.84
# No. Observations:                 510   AIC:                            -967.7
# Df Residuals:                     499   BIC:                            -921.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.1909      0.030      6.447      0.000       0.133       0.249
# ...

# %% [markdown]
# # We can cosider the above model i.e lr_5, as it seems to have very low multicolinearity between the predictors and the p-values for all the predictors seems to be significant.
# F-Statistics value of 248.4 (which is greater than 1) and the p-value of 1.47e-186 i.e almost equals to zero, states that the overall model is significant

# %%
lr_5.params
# Out:
# const             0.190855
# year              0.234132
# holiday          -0.096316
# temp              0.477737
# windspeed        -0.148098
# sep               0.090998
# Light_snowrain   -0.285031
# Misty            -0.078741
# spring           -0.055406
# summer            0.062076
# winter            0.094476
# dtype: float64

# %% [markdown]
# # Residual for train data and validation

# %%
X_train_lm_5
# Out:
#      const  year  holiday      temp  windspeed  sep  Light_snowrain  Misty  \
# 576    1.0     1        0  0.815169   0.264686    0               0      0
# 426    1.0     1        0  0.442393   0.255342    0               0      1
# 728    1.0     1        0  0.245101   0.663106    0               0      0
# 482    1.0     1        0  0.395666   0.188475    0               0      1
# 111    1.0     0        0  0.345824   0.380981    0               0      1
# ..     ...   ...      ...       ...        ...  ...             ...    ...
# 578    1.0     1        0  0.863973   0.187140    0               0      0
# 53     1.0     0        0  0.202618   0.111379    0               0      0
# 350    1.0     0        0  0.248216   0.431816    0               0      1
# 79     1.0     0        0  0.462664   0.529881    0               0      1
# 520    1.0     1        0  0.600225   0.359599    0               0      1
#
#      spring  summer  winter
# 576       0       0       0
# ...

# %%
y_train_pred = lr_5.predict(X_train_lm_5)

# %%
fig = plt.figure()
sns.distplot((y_train - y_train_pred), bins = 20)
fig.suptitle('Error Terms', fontsize = 20) 
plt.xlabel('Errors', fontsize = 22)
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Errors')

# %% [markdown]
# # normally distributed

# %%
calculateVIF(X_train_new)
# Out:
#          Features   VIF
# 3       windspeed  4.60
# 2            temp  3.84
# 0            year  2.07
# 7          spring  1.99
# 8          summer  1.90
# 9          winter  1.63
# 6           Misty  1.55
# 4             sep  1.23
# 5  Light_snowrain  1.08
# 1         holiday  1.04

# %%
plt.figure(figsize=(25,18))
sns.heatmap(X_train_new.corr(),annot = True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# # its good and there is no multicolinearity by heatmap

# %%
sm.graphics.plot_ccpr(lr_5,'temp')
plt.show()

sm.graphics.plot_ccpr(lr_5,'sep')
plt.show()

sm.graphics.plot_ccpr(lr_5,'windspeed')
plt.show()

# %%
y_train_pred = lr_5.predict(X_train_lm_5)
residual = y_train-y_train_pred
sns.scatterplot(y_train,residual)
plt.plot(y_train,(y_train-y_train),'-r')
plt.xlabel('Count')
plt.ylabel('Residual')
plt.show()
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # predictions using last model

# %%
num_vars = ['temp', 'atemp', 'humidity', 'windspeed','cnt']
df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test
# Out:
#      year  holiday  workingday      temp     atemp  humidity  windspeed  \
# 184     0        1           0  0.831783  0.769660  0.657364   0.084219
# 535     1        0           1  0.901354  0.842587  0.610133   0.153728
# 299     0        0           0  0.511964  0.496145  0.837699   0.334206
# 221     0        0           1  0.881625  0.795343  0.437098   0.339570
# 152     0        0           0  0.817246  0.741471  0.314298   0.537414
# ..    ...      ...         ...       ...       ...       ...        ...
# 702     1        0           1  0.519232  0.511907  0.756118   0.283397
# 127     0        0           1  0.584649  0.577380  0.650923   0.069510
# 640     1        0           1  0.745598  0.682653  0.817947   0.052115
# 72      0        0           1  0.331557  0.332005  0.512107   0.203418
# 653     1        0           1  0.509887  0.501133  0.575354   0.300794
#
#           cnt  aug  dec  ...  sat  sun  thu  tue  wed  Light_snowrain  Misty  \
# ...

# %%
df_test.describe()
# Out:
#              year     holiday  workingday        temp       atemp    humidity  \
# count  220.000000  220.000000  220.000000  220.000000  220.000000  220.000000
# mean     0.481818    0.036364    0.640909    0.558718    0.532847    0.638221
# std      0.500809    0.187620    0.480828    0.233187    0.217401    0.148694
# min      0.000000    0.000000    0.000000    0.046591    0.025950    0.261915
# 25%      0.000000    0.000000    0.000000    0.355429    0.344870    0.529197
# 50%      0.000000    0.000000    1.000000    0.558172    0.544652    0.625590
# 75%      1.000000    0.000000    1.000000    0.755981    0.713308    0.743798
# max      1.000000    1.000000    1.000000    0.984424    0.980934    1.002146
#
#         windspeed         cnt         aug         dec  ...         sat  \
# count  220.000000  220.000000  220.000000  220.000000  ...  220.000000
# mean     0.313293    0.522154    0.059091    0.086364  ...    0.172727
# ...

# %%
y_test = df_test.pop('cnt')
X_test = df_test

# %%
col1 = X_train_new.columns

X_test = X_test[col1]

# Adding constant variable to test dataframe
X_test_lm_5 = sm.add_constant(X_test)

# %%
y_pred = lr_5.predict(X_test_lm_5)

# %%
r2 = r2_score(y_test, y_pred)
round(r2,3)
# Out:
# 0.804

# %% [markdown]
# # model evaluation

# %%
fig = plt.figure()
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize = 25) 
plt.xlabel('y_test', fontsize = 20)
plt.ylabel('y_pred', fontsize = 20)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
round(lr_5.params,3)
# Out:
# const             0.191
# year              0.234
# holiday          -0.096
# temp              0.478
# windspeed        -0.148
# sep               0.091
# Light_snowrain   -0.285
# Misty            -0.079
# spring           -0.055
# summer            0.062
# winter            0.094
# dtype: float64

# %%
# Calculating Adjusted-R^2 value for the test dataset

adjusted_r2 = round(1-(1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1),4)
print(adjusted_r2)
# Out:
# 0.7944

# %%
plt.figure()
sns.regplot(x=y_test, y=y_pred, ci=68, fit_reg=True,scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title('y_test vs y_pred', fontsize=20)
plt.xlabel('y_test', fontsize=18)
plt.ylabel('y_pred', fontsize=16)
plt.show()

# %% [markdown]
# # Comparision between Training and Testing dataset:
# - Train dataset R^2          : 0.833
# - Test dataset R^2           : 0.8038
# - Train dataset Adjusted R^2 : 0.829
# - Test dataset Adjusted R^2  : 0.7944
#
# Demand of bikes depend on year, holiday, temp, windspeed, sep, Light_snowrain, Misty, spring, summer and winter.
